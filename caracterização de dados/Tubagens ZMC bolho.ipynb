# %%
from simpledbf import Dbf5

dbf = Dbf5('Tubagens.dbf')
df = dbf.to_dataframe()
nunique = df.nunique()
cols_to_drop = nunique[nunique == 1].index


df.drop(cols_to_drop, axis=1, inplace = True)
df.head()

"""
    ids noutros files??? 
    'OBJECTID', 'GlobalID', 'IDEntidade', 'IDInfraest', 'IDGestao','IDLocaliza',

    diametro interno dos tubos
    tub['Observacoe'].unique()


    tub['EstadoCons'].unique()
    array(['Bom', 'Razoável', 'Regular', 'bom', 'Deficiente', 'NC',
           'Razoável/Deficiente', 'Razoavel/Deficiente', 'Razoavel', 'Mau'],
          dtype=object)
    
    --- importante para ligar com caudal(ZMC_Bolho)
    tub['Observac_1'].unique()
    array([nan, 'ZMC_Sanguinheira', 'ZMC_Cantanhede', 'ZMC_Povoa da Lomba',
       'ZMC_Enxofães', 'ZMC_Outil', 'ZMC_Fornos', 'ZMC_Casal',
       'ZMC_ Varziela', 'ZMC_Portunhos', 'ZMC_Ançã', 'ZMC_Cordinhã',
       'ZMC_Praia da Tocha', 'ZMC_Tocha', 'ZMC_Sepins', 'ZMC_Murtede',
       'ZMC_Bolho', 'ZMC_Lemede', 'ZMC_Covões', 'ZMC_Cadima',
       'ZMC_Ameixoeira', 'Descarga de Superficie', 'ZMC_ Sepins',
       'ZMC_São Caetano', 'ZMCOutil', 'ZMC_Vilamar', 'ZMC_ São Caetano',
       'ZMC Vilamar', 'ZMC_ Cantanhede', 'ZMC_Póvoa da Lomba',
       'ZMC_ Pocariça', 'ZMC Cochadas'], dtype=object)
    
    --- altura
    tub['TipoCotaZ'].unique()
    ['Soleira', 'NC']
    
    --- funcao ver noutro ficheiro...
    tub['funcao'].unique()
    [3, 1, 2, 7]
    
    
    --- Tipo de escoamento
    ['Seccão cheia gravitico', 'SeccaoCheiaGravitico',
     'Seccao cheia gravitico', 'SeccaoCheiaElevatorio',
     'Secção cheia elevatoria', 'Sessão cheia gravitico', nan,
     'Seccao cheia elevatorio']
    
    -- DN  Diametro Nominal
    [ 90.,  63., 125., 160.,  75., 110.,  50.,  60., 150., 350., 250.,
    80., 200., 140., 100., 300., 500., 400., 693., 450., 800.,   0.]
    
    -- DN Interno 
    [ 0.,  1., 90.]
    
    -- PN    pressao nominal
    "pressão de serviço máxima ou pressão nominal"
    [  0,  10,  63,   1,  16, 100]
    
    Rugusidade
    [140.,   1.]
    
    TipoAssent
    ['Enterrado', 'Tunel', nan, 'CeuAberto', 'Galeria', 'Vala',
       'Apoiado', 'Aqueduto']
       
    TipoRecobr
    ['Alcatrão', 'Alcatrao', 'Asfalto', 'SemRecobrimento', nan, 'NA',
       'NC', 'Areia', 'EnvolvimentoBetao', 'AlmofadaTerraMacia']

    Shape_Leng metros?
    tub['Shape_Leng'].sum()
    685214.2183146689
          
"""

tub = df.copy()[df['Observac_1'] == 'ZMC_Bolho'][['PN', 'DN', 'EstadoCons', 'Observac_1','AnoInstala', 'Reabilitad', 'DataReabil',
       'Funcao', 'TipoAgua', 'TipoEscoam', 'Material',
       'Rugosidade', 'TipoAssent', 'TipoRecobr', 'Shape_Leng',]]
print(df.columns)
# Out:
# Index(['OBJECTID', 'GlobalID', 'IDEntidade', 'IDInfraest', 'IDGestao',
#        'IDLocaliza', 'Utilizador', 'DataDigita', 'UltimoEdit', 'DataActual',
#        'Distrito', 'Freguesia', 'Arruamento', 'Localizaca', 'Descricao',
#        'FonteInfor', 'Observacoe', 'EstadoCons', 'Observac_1', 'TipoCotaZ',
#        'AnoInstala', 'DataEntrad', 'Reabilitad', 'DataReabil', 'RegistoInt',
#        'Funcao', 'TipoAgua', 'TipoEscoam', 'Material', 'DN', 'DNInterno', 'PN',
#        'Rugosidade', 'Profundida', 'TipoAssent', 'TipoRecobr', 'Shape_Leng',
#        'Empreiteir', 'CadType', 'Color', 'LineWt', 'Layer', 'Handle',
#        'RefName', 'Class', 'LTScale', 'CadModel', 'ExtZ', 'Elevation',
#        'LyrName', 'LvlDesc', 'LyrColor', 'LyrLineWt', 'LyrOn', 'LyrHandle',
#        'TxtValue', 'TxtMemo', 'TxtGenType', 'TxtJust', 'VertAlign', 'TxtStyle',
#        'TxtFont', 'DocName', 'DocPath', 'XDList'],
#       dtype='object')

# %%
 tub.groupby(['TipoRecobr']).agg({'AnoInstala':'count', 'Shape_Leng': {'mean','min','max'} }).apply(lambda x:100 * x / float(x.sum()))
# Out:
#                 AnoInstala Shape_Leng
#                      count       mean        max        min
# TipoRecobr
# Alcatrão         91.269841  88.129753  98.616939   3.085866
# NA                0.793651  11.238186   1.252362  95.470279
# SemRecobrimento   7.936508   0.632062   0.130699   1.443855

# %%
 tub.groupby(['Material']).agg({'AnoInstala':'count', 'Shape_Leng': {'mean','min','max'} }).apply(lambda x:100 * x / float(x.sum()))
# Out:
#          AnoInstala Shape_Leng
#               count       mean        max        min
# Material
# FFD        7.142857   2.120075   1.254001  34.540103
# PVC       92.857143  97.879925  98.745999  65.459897

# %%
 tub.groupby(['AnoInstala']).agg({ 'EstadoCons':'count',  'Shape_Leng': {'mean','min','max'} } )
# Out:
#            EstadoCons  Shape_Leng
#                 count        mean          max       min
# AnoInstala
# 1997               16  105.227353  1138.869453  0.218730
# 1998              110  103.472072   648.727584  0.467478

# %%
 tub['PN'].count()
# Out:
# 126

# %%
tub.head(60)
# Out:
#       PN     DN EstadoCons Observac_1  AnoInstala  Reabilitad DataReabil  \
# 597    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 598    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 599    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 600    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 601    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 602    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 603    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 604    0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 605    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 606    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 607    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 608    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 609    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 610    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 611    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 612    0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 613    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 614    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 615    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 616    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 617    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 618    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 640    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 641    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 642    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 643    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 644    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 645    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 721    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 772    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 773    0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2514   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2515   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2516   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2517   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2518   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2519   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2520   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2521   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2522   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2523   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2524   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2525   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2526   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2527   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2528   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2529   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2530   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2531   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2532   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2533   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2534   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2535   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2536   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2537   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2538   0   90.0        Bom  ZMC_Bolho        1998           0        NaN
# 2539   0  125.0        Bom  ZMC_Bolho        1998           0        NaN
# 2540   0   63.0        Bom  ZMC_Bolho        1998           0        NaN
# 2541   0  125.0        Bom  ZMC_Bolho        1998           0        NaN
# 2542   0  125.0        Bom  ZMC_Bolho        1998           0        NaN
#
#       Funcao      TipoAgua              TipoEscoam Material  Rugosidade  \
# 597        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 598        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 599        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 600        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 601        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 602        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 603        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 604        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 605        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 606        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 607        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 608        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 609        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 610        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 611        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 612        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 613        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 614        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 615        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 616        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 617        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 618        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 640        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 641        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 642        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 643        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 644        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 645        3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 721        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 772        3   AguaPotavel  Seccão cheia gravitico      PVC       140.0
# 773        3     AguaBruta  Seccão cheia gravitico      PVC       140.0
# 2514       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2515       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2516       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2517       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2518       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2519       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2520       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2521       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2522       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2523       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2524       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2525       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2526       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2527       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2528       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2529       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2530       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2531       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2532       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2533       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2534       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2535       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2536       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2537       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2538       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2539       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2540       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0
# 2541       3  Agua Potavel  Seccão cheia gravitico      PVC       140.0