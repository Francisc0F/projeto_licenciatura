# %%
import pandas as pd
import matplotlib.pyplot as plt 
from pandas import Series
import seaborn as sns

dfCaudal = pd.read_excel(r'caudal.xlsx')
dfCaudal = pd.DataFrame(dfCaudal, columns=['Tempo', 'Caudal'])

dfCaudal['Tempo'] = pd.to_datetime(dfCaudal['Tempo'])

#dfCaudal = dfCaudal[dfCaudal.Tempo.between('2019-06-1', '2022-09-01')]
"""
series = Series(dfCaudal['Caudal'])
series.describe()
"""
dfCaudal['Caudal'] = pd.to_numeric(dfCaudal['Caudal'], errors='coerce')
dfCaudal = dfCaudal[dfCaudal['Tempo'] < '9/14/2022']

# %%
#fig, axis = plt.subplots(figsize =(10, 5))
#bins =  range(22)

#mesEAnoHist('2020', 0.1)
#mesEAnoHist('2021', 0.5)
#mesEAnoHist('2022', 0.9)

# %%
def caudalMesEntre(time1, time2):
    return dfCaudal["Caudal"][dfCaudal["Tempo"] > time1][dfCaudal["Tempo"] < time2].copy()

# %%
def mesEAnoHist(ano, alpha):
    axis.hist(caudalMesEntre(f'{ano}-1-1', f'{ano}-2-1'), bins, color='red', alpha=alpha)
    axis.hist(caudalMesEntre(f'{ano}-2-1', f'{ano}-3-1'), bins, color='lime', alpha=alpha)
    axis.hist(caudalMesEntre(f'{ano}-3-1', f'{ano}-4-1'), bins, color='blue',alpha=alpha)
    axis.hist(caudalMesEntre(f'{ano}-4-1', f'{ano}-5-1'), bins, color='pink', alpha=alpha)

# %%
def plotCaudal(time1, time2, label):
    cau = dfCaudal[dfCaudal['Tempo'] > time1][dfCaudal['Tempo'] < time2]
    plt.plot(cau.Tempo, cau.Caudal, label=label)
    leg = plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.ylabel('Volume (m3)')
    plt.xlabel('Tempo (h)')
    plt.grid(True)

# %%
weekVariation = dfCaudal.copy()
weekVariation['dayofweek'] = weekVariation['Tempo'].dt.dayofweek
#filtro de valores pouco vulgares = limpeza de valores exessivos

print(weekVariation[weekVariation['Caudal'] > 20])

weekVariation = weekVariation[weekVariation['Caudal'] < 90]

weekVariation['month'] = weekVariation['Tempo'].dt.month
weekVariation.set_index(["month","dayofweek"], inplace = True)
from calendar import month_abbr
print(month_abbr)

dfp = pd.pivot_table(data=weekVariation, index='dayofweek', columns='month', values='Caudal', aggfunc='mean')
print(weekVariation.Caudal.max())
print(dfp)


ax = dfp.plot(ylabel='Aggregated Mean', figsize=(6, 4), cmap='tab20')
ax.set_xticks(range(7)) # set ticks for all months
ax.set_xticklabels( ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left', labels = month_abbr[1:])

ax.grid(True)
# Out:
#                     Tempo  Caudal  dayofweek
# 3664  2020-06-02 16:00:00   20.38          1
# 3856  2020-06-10 16:00:00   20.17          2
# 4700  2020-07-15 20:29:15   20.16          2
# 4749  2020-07-17 21:29:18   20.50          4
# 4821  2020-07-20 21:29:18   21.30          0
# ...                   ...     ...        ...
# 22409 2022-08-11 07:00:00   33.22          3
# 22899 2022-08-31 12:00:00   27.40          2
# 22901 2022-08-31 13:00:00   23.82          2
# 22903 2022-08-31 14:00:00   22.08          2
# 22905 2022-08-31 15:00:00   24.20          2
#
# [184 rows x 3 columns]
# <calendar._localized_month object at 0x00000226834F3400>
# 89.22
# month            1         2         3         4         5          6   \
# dayofweek
# 0          5.927147  5.938276  6.070357  6.749336  7.514345   8.598358
# 1          5.794325  5.908931  6.136083  6.657684  7.663397   8.944236
# 2          5.876000  6.020069  6.180240  6.829135  7.704583   8.782838
# 3          5.875142  5.949483  6.178237  6.695988  7.881806   9.069310
# 4          5.744286  6.015280  6.100069  6.621964  7.842596   8.255253
# 5          6.452700  6.611154  6.884236  7.313365  8.228571  10.284679
# 6          6.003988  6.124306  6.472136  6.683229  7.588167   8.632131
#
# month             7          8         9         10         11        12
# dayofweek
# 0           9.911610   9.647750  6.744330  4.272841   7.604529  6.466667
# 1          10.342535   9.647351  6.695224  4.275076   6.190833  6.550417
# 2          10.708077   9.750895  6.401220  4.540458   6.185476  6.410456
# 3          10.422679   9.452740  6.409970  4.637214   6.130833  6.652231
# 4          10.878000   9.238021  6.223654  7.353798   6.363444  6.595972
# 5          10.550618  10.205032  7.360625  9.115309   6.939223  7.034427
# 6           9.987276   9.511752  7.037187  4.898681  11.987056  6.636615

# %%
dfp.head(12*3)
# Out:
# month            1         2         3         4         5          6   \
# dayofweek
# 0          5.927147  5.938276  6.070357  6.749336  7.514345   8.598358
# 1          5.794325  5.908931  6.136083  6.657684  7.663397   8.944236
# 2          5.876000  6.020069  6.180240  6.829135  7.704583   8.782838
# 3          5.875142  5.949483  6.178237  6.695988  7.881806   9.069310
# 4          5.744286  6.015280  6.100069  6.621964  7.842596   8.255253
# 5          6.452700  6.611154  6.884236  7.313365  8.228571  10.284679
# 6          6.003988  6.124306  6.472136  6.683229  7.588167   8.632131
#
# month             7          8         9          10         11        12
# dayofweek
# 0           9.911610   9.647750  8.076543   5.875156   7.604529  6.466667
# 1          10.342535   9.647351  7.912538   5.878229   6.190833  6.550417
# 2          10.708077   9.750895  7.927576   5.675573   6.185476  6.410456
# 3          10.422679   9.452740  8.158144   5.677336   6.130833  6.652231
# 4          10.878000   9.238021  8.090750   8.830711   6.363444  6.595972
# 5          10.550618  10.205032  8.832750  11.908085   6.939223  7.034427
# 6           9.987276   9.511752  8.444625   6.531574  11.987056  6.636615

# %%
dfp.plot.hist(bins=12, alpha=0.9, cmap='tab20')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
dfp.plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
dfp.plot(kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
dfp.plot(kind='area')
# Out:
# <AxesSubplot: xlabel='dayofweek'>

# %%
checkStrangeValues = dfCaudal.copy()

checkStrangeValues = checkStrangeValues[checkStrangeValues['Tempo'] > '2022-05-10']
checkStrangeValues['diff'] = checkStrangeValues.Caudal.diff()
checkStrangeValues['diff']= checkStrangeValues['diff'].fillna(0)
checkStrangeValues.head()
# Out:
#                     Tempo  Caudal  diff
# 20495 2022-05-10 00:36:38    6.47  0.00
# 20496 2022-05-10 01:36:38    5.89 -0.58
# 20497 2022-05-10 02:36:38    5.34 -0.55
# 20498 2022-05-10 03:36:38    5.28 -0.06
# 20499 2022-05-10 04:36:40    5.27 -0.01

# %%
valuesToCheck = checkStrangeValues.copy()
valuesToCheck["hora"] = valuesToCheck.Tempo.dt.hour
valuesToCheck = valuesToCheck[valuesToCheck["Tempo"] > '2022-06-17'][valuesToCheck["Tempo"] < '2022-06-18']
plt.plot(valuesToCheck["hora"], valuesToCheck['diff'])
# Out:
# C:\Users\Francisco\AppData\Local\Temp\ipykernel_14596\438222098.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   valuesToCheck = valuesToCheck[valuesToCheck["Tempo"] > '2022-06-17'][valuesToCheck["Tempo"] < '2022-06-18']

# %%
caudaldiario = dfCaudal.resample('D').mean()
caudaldiario= caudaldiario.loc['2022-01-01':]
caudaldiario.head()
caudaldiario.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 caudaldiario = dfCaudal.resample('D').mean()
#       2 caudaldiario= caudaldiario.loc['2022-01-01':]
#       3 caudaldiario.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:11379, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#   11362 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   11363 def resample(
#   11364     self,
#    (...)
#   11377     group_keys: bool | lib.NoDefault = no_default,
#   11378 ) -> Resampler:
# > 11379     return super().resample(
#   11380         rule=rule,
#   11381         axis=axis,
#   11382         closed=closed,
#   11383         label=label,
#   11384         convention=convention,
#   11385         kind=kind,
#   11386         loffset=loffset,
#   11387         base=base,
#   11388         on=on,
#   11389         level=level,
#   11390         origin=origin,
#   11391         offset=offset,
#   11392         group_keys=group_keys,
#   11393     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:8858, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    8855 from pandas.core.resample import get_resampler
#    8857 axis = self._get_axis_number(axis)
# -> 8858 return get_resampler(
#    8859     self,
#    8860     freq=rule,
#    8861     label=label,
#    8862     closed=closed,
#    8863     axis=axis,
#    8864     kind=kind,
#    8865     loffset=loffset,
#    8866     convention=convention,
#    8867     base=base,
#    8868     key=on,
#    8869     level=level,
#    8870     origin=origin,
#    8871     offset=offset,
#    8872     group_keys=group_keys,
#    8873 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\resample.py:1544, in get_resampler(obj, kind, **kwds)
#    1540 """
#    1541 Create a TimeGrouper and return our resampler.
#    1542 """
#    1543 tg = TimeGrouper(**kwds)
# -> 1544 return tg._get_resampler(obj, kind=kind)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\resample.py:1725, in TimeGrouper._get_resampler(self, obj, kind)
#    1720 elif isinstance(ax, TimedeltaIndex):
#    1721     return TimedeltaIndexResampler(
#    1722         obj, groupby=self, axis=self.axis, group_keys=self.group_keys
#    1723     )
# -> 1725 raise TypeError(
#    1726     "Only valid with DatetimeIndex, "
#    1727     "TimedeltaIndex or PeriodIndex, "
#    1728     f"but got an instance of '{type(ax).__name__}'"
#    1729 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
caudaldiario.index.dt.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 caudaldiario.index.dt.year
#
# NameError: name 'caudaldiario' is not defined
